# %% [markdown]
# # Business problem

# %% [markdown]
# # Data Context

# %% [markdown]
# # 0.0 Imports

# %%
# Data manipulation
import pandas as pd
import numpy as np

from IPython.display import HTML

# Set float values to display only two decimals
pd.set_option('display.float_format', lambda x: '%.2f' % x)


# Data visualization
from matplotlib import pyplot as plt
import plotly.express as px
import seaborn as sns
import folium

# %% [markdown]
# # 0.1 Helper Functions

# %%
def jupyter_settings():
    # %matplotlib inline
    
    plt.style.use('bmh')
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 40
    
    display(HTML('<style>.container {width:100% !important;}</style>'))
    pd.options.display.max_columns = None
    pd.set_option('display.expand_frame_repr', False)
    
    sns.set()

jupyter_settings()
# Out:
# <style>.container {width:100% !important;}</style>

# %% [markdown]
# # 0.2 Reading the data

# %%
data = pd.read_csv('datasets/airbnb_ny_2019.csv')

data.head()
# Out:
#      id                                              name  host_id    host_name neighbourhood_group neighbourhood  latitude  longitude        room_type  price  minimum_nights  number_of_reviews last_review  reviews_per_month  calculated_host_listings_count  availability_365
# 0  2539                Clean & quiet apt home by the park     2787         John            Brooklyn    Kensington     40.65     -73.97     Private room    149               1                  9  2018-10-19               0.21                               6               365
# 1  2595                             Skylit Midtown Castle     2845     Jennifer           Manhattan       Midtown     40.75     -73.98  Entire home/apt    225               1                 45  2019-05-21               0.38                               2               355
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth           Manhattan        Harlem     40.81     -73.94     Private room    150               3                  0         NaN                NaN                               1               365
# 3  3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne            Brooklyn  Clinton Hill     40.69     -73.96  Entire home/apt     89               1                270  2019-07-05               4.64                               1               194
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura           Manhattan   East Harlem     40.80     -73.94  Entire home/apt     80              10                  9  2018-11-19               0.10                               1                 0

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Checking the columns in the dataset

# %%
print(f'The columns of the dataset are: \n {data.columns.tolist()}' )
# Out:
# The columns of the dataset are:
#  ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# %% [markdown]
# ## Data description

# %% [markdown]
# ### Rows, columns and data types

# %%
print(f' The dataset contains {data.shape[0]} rows and {data.shape[1]} columns' )
print('\n')
print(f'The types of the columns are: \n {data.dtypes}')
# Out:
#  The dataset contains 48895 rows and 16 columns
#
#
# The types of the columns are:
#  id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# ## Transforming the data type of column 'last_review' from object to datetime

# %%
data['last_review'] = pd.to_datetime(data['last_review'], format = '%Y-%m-%d')

data['last_review'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## Checking missing values

# %%
data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ## Descriptive Statistics

# %%
num_attributes = data.select_dtypes(include = ['float64', 'int64'])
num_attributes
# Out:
#              id   host_id  latitude  longitude  price  minimum_nights  number_of_reviews  reviews_per_month  calculated_host_listings_count  availability_365
# 0          2539      2787     40.65     -73.97    149               1                  9               0.21                               6               365
# 1          2595      2845     40.75     -73.98    225               1                 45               0.38                               2               355
# 2          3647      4632     40.81     -73.94    150               3                  0                NaN                               1               365
# 3          3831      4869     40.69     -73.96     89               1                270               4.64                               1               194
# 4          5022      7192     40.80     -73.94     80              10                  9               0.10                               1                 0
# ...         ...       ...       ...        ...    ...             ...                ...                ...                             ...               ...
# 48890  36484665   8232441     40.68     -73.95     70               2                  0                NaN                               2                 9
# 48891  36485057   6570630     40.70     -73.93     40               4                  0                NaN                               2                36
# 48892  36485431  23492952     40.81     -73.95    115              10                  0                NaN                               1                27
# 48893  36485609  30985759     40.76     -73.99     55               1                  0                NaN                               6                 2
# 48894  36487245  68119814     40.76     -73.99     90               7                  0                NaN                               1                23
#
# [48895 rows x 10 columns]

# %%
num_attributes.drop(columns=['id', 'host_id', 'latitude', 'longitude'])
num_attributes.describe().transpose()
# Out:
#                                   count        mean         std     min        25%         50%          75%          max
# id                             48895.00 19017143.24 10983108.39 2539.00 9471945.00 19677284.00  29152178.50  36487245.00
# host_id                        48895.00 67620010.65 78610967.03 2438.00 7822033.00 30793816.00 107434423.00 274321313.00
# latitude                       48895.00       40.73        0.05   40.50      40.69       40.72        40.76        40.91
# longitude                      48895.00      -73.95        0.05  -74.24     -73.98      -73.96       -73.94       -73.71
# price                          48895.00      152.72      240.15    0.00      69.00      106.00       175.00     10000.00
# minimum_nights                 48895.00        7.03       20.51    1.00       1.00        3.00         5.00      1250.00
# number_of_reviews              48895.00       23.27       44.55    0.00       1.00        5.00        24.00       629.00
# reviews_per_month              38843.00        1.37        1.68    0.01       0.19        0.72         2.02        58.50
# calculated_host_listings_count 48895.00        7.14       32.95    1.00       1.00        1.00         2.00       327.00
# availability_365               48895.00      112.78      131.62    0.00       0.00       45.00       227.00       365.00

# %% [markdown]
# # Business Questions

# %% [markdown]
# ## What are the different accommodations types offered by the hosts?

# %%
accommodation = data['room_type'].unique()

print(f' The different accommodations are {accommodation[0]}, {accommodation[1]} and {accommodation[2]}')
# Out:
#  The different accommodations are Private room, Entire home/apt and Shared room

# %% [markdown]
# ## How many hosts we have in the database?

# %%
unique_host = len(data['host_id'].unique())

print(f' The are {unique_host} unique hosts in the database')
# Out:
#  The are 37457 unique hosts in the database

# %% [markdown]
# ## How is the price variation of accommodations in New York City?

# %%
# Calculate the standard deviation for the price column

price_std = np.round(data['price'].std(), 2)
price_mean = np.round(data['price'].mean(), 2)

print(f' The price variation in NYC is U${price_std}, what indicates a wide price range, since the mean price is U${price_mean}')
# Out:
#  The price variation in NYC is U$240.15, what indicates a wide price range, since the mean price is U$152.72

# %% [markdown]
# ## What is the price distribution? There are more cheap or expensive accommodations?

# %%
#plt.figure(figsize = (20,5))
#plt.hist(data['price'], bins=100);

px.histogram(data[data['price'] < 2000], 'price', nbins=50 )

# %%
print('There are more properties listing with low cost rent and a few with high cost, as the histogram shows us.')
# Out:
# There are more properties listing with low cost rent and a few with high cost, as the histogram shows us.

# %% [markdown]
# ## What is the highest price among accommodations avaiable to rent per region?

# %%
df1 = data[data['availability_365'] > 0]
data_plot = df1[['neighbourhood_group', 'price']].groupby('neighbourhood_group').max().reset_index()

px.bar(data_plot, x='neighbourhood_group', y='price', title= 'Max rent price per region', text_auto=True)

# %% [markdown]
# ## Can we know where these accomodations are?

# %%
cols = ['neighbourhood_group', 'price', 'latitude', 'longitude' ]

data_map = df1.loc[:, cols].groupby('neighbourhood_group').max().reset_index()

data_map
# Out:
#   neighbourhood_group  price  latitude  longitude
# 0               Bronx   2500     40.91     -73.78
# 1            Brooklyn   8000     40.74     -73.86
# 2           Manhattan  10000     40.88     -73.91
# 3              Queens   2600     40.80     -73.71
# 4       Staten Island   5000     40.65     -74.06

# %%
map = folium.Map(location = [40.712776, -74.005974], zoom_start=11)

for i, c in data_map.iterrows():
    folium.Marker([c['latitude'], c['longitude']]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffe6edc21bde41584379df9090b32e6c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffe6edc21bde41584379df9090b32e6c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ffe6edc21bde41584379df9090b32e6c = L.map(
#                 &quot;map_ffe6edc21bde41584379df9090b32e6c&quot;,
#                 {
#                     center: [40.712776, -74.005974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80c1791db6961a74f03b7286ba86a4f6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ffe6edc21bde41584379df9090b32e6c);
#
#
#             var marker_a570b96c54f3e2dd5e4f15e1cb98bc4b = L.marker(
#                 [40.91306, -73.78158],
#                 {}
#             ).addTo(map_ffe6edc21bde41584379df9090b32e6c);
#
#
#             var marker_4b1e104a860c325cd43df03d42483453 = L.marker(
#                 [40.7389, -73.85676],
#                 {}
#             ).addTo(map_ffe6edc21bde41584379df9090b32e6c);
#
#
#             var marker_760cbedf732f75e74d4e79c2dc21676c = L.marker(
#                 [40.87665, -73.90855],
#                 {}
#             ).addTo(map_ffe6edc21bde41584379df9090b32e6c);
#
#
#             var marker_4b2075e9445818b6516ac9f0a30268eb = L.marker(
#                 [40.79721, -73.71299],
#                 {}
#             ).addTo(map_ffe6edc21bde41584379df9090b32e6c);
#
#
#             var marker_12d14e99762c17bac9bf36681b92320b = L.marker(
#                 [40.64779, -74.06092],
#                 {}
#             ).addTo(map_ffe6edc21bde41584379df9090b32e6c);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Can we identify the accommodations in a map by color indicating their room type?

# %%
cols = ['neighbourhood_group', 'room_type', 'latitude', 'longitude' ]

data_map = df1.loc[:, cols].sample( 100 )

data_map['color'] = 'NA'

data_map.loc[data_map['room_type'] == 'Private room', 'color' ] = 'darkgreen'
data_map.loc[data_map['room_type'] == 'Entire home/apt', 'color' ] = 'darkred'
data_map.loc[data_map['room_type'] == 'Shared room', 'color' ] = 'darkblue'

data_map
# Out:
#       neighbourhood_group        room_type  latitude  longitude      color
# 24004            Brooklyn  Entire home/apt     40.69     -73.94    darkred
# 32887            Brooklyn  Entire home/apt     40.68     -74.00    darkred
# 6317            Manhattan     Private room     40.82     -73.94  darkgreen
# 46427           Manhattan  Entire home/apt     40.81     -73.95    darkred
# 44305               Bronx  Entire home/apt     40.88     -73.85    darkred
# ...                   ...              ...       ...        ...        ...
# 45924            Brooklyn     Private room     40.69     -73.93  darkgreen
# 4160             Brooklyn  Entire home/apt     40.69     -73.97    darkred
# 3238             Brooklyn  Entire home/apt     40.69     -73.97    darkred
# 19728           Manhattan     Private room     40.72     -73.98  darkgreen
# 15115            Brooklyn     Private room     40.68     -73.90  darkgreen
#
# [100 rows x 5 columns]

# %%
map = folium.Map(location = [40.712776, -74.005974], zoom_start=11)

for i, c in data_map.iterrows():
    folium.Marker(  [c['latitude'], c['longitude']],
                    popup=c['room_type'],
                    icon=folium.Icon(color = c['color'])).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_946273e3e74759a419dc2e2c3f5dfba1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_946273e3e74759a419dc2e2c3f5dfba1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_946273e3e74759a419dc2e2c3f5dfba1 = L.map(
#                 &quot;map_946273e3e74759a419dc2e2c3f5dfba1&quot;,
#                 {
#                     center: [40.712776, -74.005974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0ad8b8601f29a2ff1125bf92d6d2dca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_946273e3e74759a419dc2e2c3f5dfba1);
#
#
#             var marker_3bbd1d4bb588fe783b442ec9f20a9245 = L.marker(
#                 [40.68627, -73.94106],
#                 {}
#             ).addTo(map_946273e3e74759a419dc2e2c3f5dfba1);
#
#
#             var icon_265f494323e2cb8340c18e2c7922ef9e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3bbd1d4bb588fe783b442ec9f20a9245.setIcon(icon_265f494323e2cb8340c18e2c7922ef9e);
#
#
#         var popup_2aff22bce717d916ec651d3d9fa50ca7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_292072b686db18b3b6761c9c8c2bbbce = $(`&lt;div id=&quot;html_292072b686db18b3b6761c9c8c2bbbce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Entire home/apt&lt;/div&gt;`)[0];
#             popup_2aff22bce717d916ec651d3d9fa50ca7.setContent(html_292072b686db18b3b6761c9c8c2bbbce);
#
#
#         marker_3bbd1d4bb588fe783b442ec9f20a9245.bindPopup(popup_2aff22bce717d916ec651d3d9fa50ca7)
#         ;
#
#
#
#
#             var marker_235964d0cafbc732ea9aa50ecc856bca = L.marker(
#                 [40.68051, -74.00357],
#                 {}
#             ).addTo(map_946273e3e74759a419dc2e2c3f5dfba1);
#
#
#             var icon_2067551b7f28980e5f558cc523c3e700 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_235964d0cafbc732ea9aa50ecc856bca.setIcon(icon_2067551b7f28980e5f558cc523c3e700);
#
#
#         var popup_f4180c19bc4438a073738a3efc75f605 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a1b3e05ed1ef575cca4cc537a0eeb428 = $(`&lt;div id=&quot;html_a1b3e05ed1ef575cca4cc537a0eeb428&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Entire home/apt&lt;/div&gt;`)[0];
#             popup_f4180c19bc4438a073738a3efc75f605.setContent(html_a1b3e05ed1ef575cca4cc537a0eeb428);
#
#
#         marker_235964d0cafbc732ea9aa50ecc856bca.bindPopup(popup_f4180c19bc4438a073738a3efc75f605)
#         ;
#
#
#
#
#             var marker_c056aec7dcb6f5b053a9522907a606e2 = L.marker(
#                 [40.82351, -73.94047],
#                 {}
#             ).addTo(map_946273e3e74759a419dc2e2c3f5dfba1);
#
#
#             var icon_4c36b79e749fa604b6a4c679b44c6b25 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c056aec7dcb6f5b053a9522907a606e2.setIcon(icon_4c36b79e749fa604b6a4c679b44c6b25);
#
#
#         var popup_c835d368f30bc2edd43c0d9af18d0f35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_44e4c39fd604ca5a98a88f435f796b36 = $(`&lt;div id=&quot;html_44e4c39fd604ca5a98a88f435f796b36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Private room&lt;/div&gt;`)[0];
#             popup_c835d368f30bc2edd43c0d9af18d0f35.setContent(html_44e4c39fd604ca5a98a88f435f796b36);
#
#
#         marker_c056aec7dcb6f5b053a9522907a606e2.bindPopup(popup_c835d368f30bc2edd43c0d9af18d0f35)
#         ;
#
#
#
#
#             var marker_62d51ec2f78566c4611bcbc30ae8ab3b = L.marker(
#                 [40.80618, -73.94618],
#                 {}
#             ).addTo(map_946273e3e74759a419dc2e2c3f5dfba1);
#
#
#             var icon_149e764f66af9d38347fbb5b88af0ae7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_62d51ec2f78566c4611bcbc30ae8ab3b.setIcon(icon_149

# %% [markdown]
# ## What are the top 10 reviews accommodations by region?

# %%
cols = ['neighbourhood_group', 'latitude', 'longitude', 'number_of_reviews']

data_map = data.loc[:, cols].sort_values('number_of_reviews', ascending=False).groupby('neighbourhood_group').head(10).reset_index(drop=True)
data_map.sort_values(['neighbourhood_group', 'number_of_reviews'], ascending=[True, False]).reset_index(drop=True)
# Out:
#    neighbourhood_group  latitude  longitude  number_of_reviews
# 0                Bronx     40.81     -73.92                321
# 1                Bronx     40.84     -73.91                291
# 2                Bronx     40.81     -73.93                276
# 3                Bronx     40.86     -73.86                271
# 4                Bronx     40.83     -73.83                266
# 5                Bronx     40.83     -73.92                258
# 6                Bronx     40.83     -73.92                235
# 7                Bronx     40.81     -73.92                231
# 8                Bronx     40.85     -73.78                227
# 9                Bronx     40.83     -73.93                219
# 10            Brooklyn     40.68     -73.98                488
# 11            Brooklyn     40.70     -73.92                480
# 12            Brooklyn     40.67     -73.99                467
# 13            Brooklyn     40.69     -73.96                426
# 14            Brooklyn     40.71     -73.96                404
# 15            Brooklyn     40.66     -73.96                401
# 16            Brooklyn     40.67     -73.99                398
# 17            Brooklyn     40.69     -73.94                397
# 18            Brooklyn     40.71     -73.94                385
# 19            Brooklyn     40.67     -73.99                378
# 20           Manhattan     40.82     -73.94                607
# 21           Manhattan     40.82     -73.94                597
# 22           Manhattan     40.82     -73.94                594
# 23           Manhattan     40.72     -73.99                540
# 24           Manhattan     40.83     -73.94                458
# 25           Manhattan     40.73     -73.98                451
# 26           Manhattan     40.72     -74.00                447
# 27           Manhattan     40.83     -73.94                439
# 28           Manhattan     40.76     -73.98                430
# 29           Manhattan     40.73     -73.98                414
# 30              Queens     40.67     -73.77                629
# 31              Queens     40.67     -73.77                576
# 32              Queens     40.77     -73.88                543
# 33              Queens     40.76     -73.87                510
# 34              Queens     40.76     -73.82                474
# 35              Queens     40.77     -73.88                466
# 36              Queens     40.77     -73.88                459
# 37              Queens     40.68     -73.76                454
# 38              Queens     40.77     -73.88                448
# 39              Queens     40.75     -73.91                441
# 40       Staten Island     40.63     -74.09                333
# 41       Staten Island     40.62     -74.07                242
# 42       Staten Island     40.64     -74.08                234
# 43       Staten Island     40.63     -74.12                196
# 44       Staten Island     40.64     -74.09                193
# 45       Staten Island     40.63     -74.08                177
# 46       Staten Island     40.64     -74.09                177
# 47       Staten Island     40.65     -74.08                166
# 48       Staten Island     40.64     -74.08                157
# 49       Staten Island     40.62     -74.09                151

# %%
map = folium.Map(location = [40.712776, -74.005974], zoom_start=11)

for i, c in data_map.iterrows():
    folium.Marker(  [c['latitude'], c['longitude']],
                    popup=c['neighbourhood_group']).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fdc5975182e36224476dcf2b1e97a0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fdc5975182e36224476dcf2b1e97a0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5fdc5975182e36224476dcf2b1e97a0f = L.map(
#                 &quot;map_5fdc5975182e36224476dcf2b1e97a0f&quot;,
#                 {
#                     center: [40.712776, -74.005974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c2899ba110390dedf1ae3b51555fb46 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5fdc5975182e36224476dcf2b1e97a0f);
#
#
#             var marker_54bfbdf7d66d09073196370fb7d52dce = L.marker(
#                 [40.6673, -73.76831],
#                 {}
#             ).addTo(map_5fdc5975182e36224476dcf2b1e97a0f);
#
#
#         var popup_acae4fc276791fe8725abe6b53aff5ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4942323494ddf491b780f002914d9e9d = $(`&lt;div id=&quot;html_4942323494ddf491b780f002914d9e9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Queens&lt;/div&gt;`)[0];
#             popup_acae4fc276791fe8725abe6b53aff5ce.setContent(html_4942323494ddf491b780f002914d9e9d);
#
#
#         marker_54bfbdf7d66d09073196370fb7d52dce.bindPopup(popup_acae4fc276791fe8725abe6b53aff5ce)
#         ;
#
#
#
#
#             var marker_a89e1664c94edb57980ef2f8de60a78e = L.marker(
#                 [40.82085, -73.94025],
#                 {}
#             ).addTo(map_5fdc5975182e36224476dcf2b1e97a0f);
#
#
#         var popup_46568119505cf207cdc725e429884835 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ca5d313c2af3da2aa4fc6a5009b1ef8c = $(`&lt;div id=&quot;html_ca5d313c2af3da2aa4fc6a5009b1ef8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#             popup_46568119505cf207cdc725e429884835.setContent(html_ca5d313c2af3da2aa4fc6a5009b1ef8c);
#
#
#         marker_a89e1664c94edb57980ef2f8de60a78e.bindPopup(popup_46568119505cf207cdc725e429884835)
#         ;
#
#
#
#
#             var marker_d2eba54445321a662b9c2b55213de070 = L.marker(
#                 [40.82124, -73.93838],
#                 {}
#             ).addTo(map_5fdc5975182e36224476dcf2b1e97a0f);
#
#
#         var popup_0c374c88b3fa5aab1b562235cc0ba9b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cc7c31f5f4b78f58454863aaa4d304bf = $(`&lt;div id=&quot;html_cc7c31f5f4b78f58454863aaa4d304bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#             popup_0c374c88b3fa5aab1b562235cc0ba9b8.setContent(html_cc7c31f5f4b78f58454863aaa4d304bf);
#
#
#         marker_d2eba54445321a662b9c2b55213de070.bindPopup(popup_0c374c88b3fa5aab1b562235cc0ba9b8)
#         ;
#
#
#
#
#             var marker_649fb9cf7b38b34f79ee4b0a0fbec339 = L.marker(
#                 [40.82264, -73.94041],
#                 {}
#             ).addTo(map_5fdc5975182e36224476dcf2b1e97a0f);
#
#
#         var popup_840804f1534533d69db8f7ef6ea9db0f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_db9456687c621ee9de9475e1d5dba407 = $(`&lt;div id=&quot;html_db9456687c621ee9de9475e1d5dba407&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#             popup_840804f1534533d69db8f7ef6ea9db0f.setContent(html_db9456687c621ee9de9475e1d5dba407);
#
#
#         marker_649fb9cf7b38b34f79ee4b0a0fbec339.bindPopup(popup_840804f1534533d69db8f7ef6ea9db0f)
#         ;
#
#
#
#
#             var marker_bc88afc2c8a7b4c53bf9550dbe58a73e = L.marker(
#                 [40.66939, -73.76975],
#                 {}
#             ).addTo(map_5fdc5975182e36224476dcf2b1e97a0f);
#
#
#         var popup_c59bc07597ce193d4dd0de51ac14a845 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_48db206b6f0555a8a91c8c477e74798d = $(`&lt;div id=&quot;html_48db206b6f0555a8a91c8c477e74798d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Queens&lt;/div&gt;`)[0];
#             popup_c59bc07597ce193d4dd0de51ac14a845.setContent(html_48db206b6f0555a8a91c8c477e74798d);
#
#
#         marker_bc88afc2c8a7b4c53bf9550dbe58a73e.bindPopup(popup_c59bc07597ce193d4dd0de51ac14a845)
#         ;
#
#
#
#
#             var marker_98de97eb205e5547866e5cae4fe6930a = L.marker(
#                 [40.77006, -73.87683],
#                 {}
#             ).addTo(map_5fdc5975182e36224476dcf2b1e97a0f);
#
#
#         var popup_2438b0f363ea696a0f4e1f9de83c807c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c00d1ebaf098980d4c52196efecb4852 = $(`&lt;div id=&quot;html_c00d1ebaf098980d4c52196efecb4852&quot; style=&quot;width: 100.0%; hei

# %% [markdown]
# ## What are the top 50 highest prices?

# %%
cols = ['neighbourhood_group', 'latitude', 'longitude', 'price']

data_map = data.loc[:, cols].sort_values('price', ascending=False).head(50).reset_index(drop=True)
data_map.sort_values('price', ascending=False)
# Out:
#    neighbourhood_group  latitude  longitude  price
# 0               Queens     40.77     -73.92  10000
# 1             Brooklyn     40.73     -73.96  10000
# 2            Manhattan     40.77     -73.99  10000
# 3            Manhattan     40.72     -73.99   9999
# 4            Manhattan     40.71     -73.99   9999
# 5            Manhattan     40.79     -73.94   9999
# 6            Manhattan     40.72     -74.01   8500
# 7             Brooklyn     40.69     -73.97   8000
# 8            Manhattan     40.77     -73.96   7703
# 9            Manhattan     40.71     -74.02   7500
# 10            Brooklyn     40.66     -73.92   7500
# 11           Manhattan     40.75     -74.00   6800
# 12           Manhattan     40.77     -73.98   6500
# 13            Brooklyn     40.69     -73.96   6500
# 14           Manhattan     40.71     -74.01   6500
# 15           Manhattan     40.79     -73.95   6419
# 16           Manhattan     40.78     -73.98   6000
# 17           Manhattan     40.73     -74.00   6000
# 18           Manhattan     40.72     -74.00   5250
# 19           Manhattan     40.74     -73.98   5100
# 23            Brooklyn     40.68     -73.88   5000
# 24           Manhattan     40.72     -73.99   5000
# 25            Brooklyn     40.70     -73.96   5000
# 22           Manhattan     40.83     -73.95   5000
# 21            Brooklyn     40.69     -73.92   5000
# 20       Staten Island     40.64     -74.10   5000
# 26            Brooklyn     40.72     -73.96   4500
# 27            Brooklyn     40.69     -73.97   4500
# 28            Brooklyn     40.69     -73.95   4200
# 29            Brooklyn     40.63     -74.02   4200
# 30           Manhattan     40.75     -74.00   4160
# 31           Manhattan     40.76     -73.99   4100
# 32           Manhattan     40.74     -74.01   4000
# 33           Manhattan     40.79     -73.97   4000
# 34            Brooklyn     40.68     -73.97   4000
# 35           Manhattan     40.73     -73.99   3900
# 36           Manhattan     40.73     -73.99   3800
# 37           Manhattan     40.73     -73.99   3750
# 38           Manhattan     40.71     -74.02   3750
# 39           Manhattan     40.79     -73.97   3613
# 40           Manhattan     40.77     -73.97   3600
# 41           Manhattan     40.73     -73.99   3518
# 42           Manhattan     40.79     -73.97   3512
# 43           Manhattan     40.75     -74.00   3210
# 44           Manhattan     40.81     -73.95   3200
# 45           Manhattan     40.74     -73.99   3000
# 46           Manhattan     40.76     -73.99   3000
# 47           Manhattan     40.78     -73.98   3000
# 48           Manhattan     40.73     -74.01   3000
# 49           Manhattan     40.80     -73.97   3000

# %%
map = folium.Map(location = [40.712776, -74.005974], zoom_start=11)

for i, c in data_map.iterrows():
    folium.Marker(  [c['latitude'], c['longitude']],
                    popup=c['neighbourhood_group']).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6697e9c9b9ae7e126f05a799f07b7fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6697e9c9b9ae7e126f05a799f07b7fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b6697e9c9b9ae7e126f05a799f07b7fc = L.map(
#                 &quot;map_b6697e9c9b9ae7e126f05a799f07b7fc&quot;,
#                 {
#                     center: [40.712776, -74.005974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b71d5063a40724ad31e7facaa4a5ed93 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b6697e9c9b9ae7e126f05a799f07b7fc);
#
#
#             var marker_88fc47b549b4092ef798f0c1af7bf25e = L.marker(
#                 [40.7681, -73.91651],
#                 {}
#             ).addTo(map_b6697e9c9b9ae7e126f05a799f07b7fc);
#
#
#         var popup_44e666350873fd5a4088e3eb432f56f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2ac5a6116e31ae2e9dca06f23f01f63b = $(`&lt;div id=&quot;html_2ac5a6116e31ae2e9dca06f23f01f63b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Queens&lt;/div&gt;`)[0];
#             popup_44e666350873fd5a4088e3eb432f56f0.setContent(html_2ac5a6116e31ae2e9dca06f23f01f63b);
#
#
#         marker_88fc47b549b4092ef798f0c1af7bf25e.bindPopup(popup_44e666350873fd5a4088e3eb432f56f0)
#         ;
#
#
#
#
#             var marker_d4b5564afe595a5708db43fcae1ae425 = L.marker(
#                 [40.7326, -73.95739],
#                 {}
#             ).addTo(map_b6697e9c9b9ae7e126f05a799f07b7fc);
#
#
#         var popup_f9da5cd94bf36bb952155ea2f8a812dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5640d160c1b63e8c753c02d1b2893802 = $(`&lt;div id=&quot;html_5640d160c1b63e8c753c02d1b2893802&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brooklyn&lt;/div&gt;`)[0];
#             popup_f9da5cd94bf36bb952155ea2f8a812dd.setContent(html_5640d160c1b63e8c753c02d1b2893802);
#
#
#         marker_d4b5564afe595a5708db43fcae1ae425.bindPopup(popup_f9da5cd94bf36bb952155ea2f8a812dd)
#         ;
#
#
#
#
#             var marker_9f25a1ac858e739bedbd4202ee730c37 = L.marker(
#                 [40.77213, -73.98665],
#                 {}
#             ).addTo(map_b6697e9c9b9ae7e126f05a799f07b7fc);
#
#
#         var popup_e5c921b08d7d406070fbbc1892460bb4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bc2b3f12105f4da44a790aa0930bd575 = $(`&lt;div id=&quot;html_bc2b3f12105f4da44a790aa0930bd575&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#             popup_e5c921b08d7d406070fbbc1892460bb4.setContent(html_bc2b3f12105f4da44a790aa0930bd575);
#
#
#         marker_9f25a1ac858e739bedbd4202ee730c37.bindPopup(popup_e5c921b08d7d406070fbbc1892460bb4)
#         ;
#
#
#
#
#             var marker_82f0624203ed62f547dfa6d93d2d1054 = L.marker(
#                 [40.7198, -73.98566],
#                 {}
#             ).addTo(map_b6697e9c9b9ae7e126f05a799f07b7fc);
#
#
#         var popup_7dbc2f3f48d15ef44d87ba5792bdcb58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_478de5a7be38e3a2f7a9983ec5c3c020 = $(`&lt;div id=&quot;html_478de5a7be38e3a2f7a9983ec5c3c020&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#             popup_7dbc2f3f48d15ef44d87ba5792bdcb58.setContent(html_478de5a7be38e3a2f7a9983ec5c3c020);
#
#
#         marker_82f0624203ed62f547dfa6d93d2d1054.bindPopup(popup_7dbc2f3f48d15ef44d87ba5792bdcb58)
#         ;
#
#
#
#
#             var marker_5ef6a2008016d8e0183579c10da04437 = L.marker(
#                 [40.71355, -73.98507],
#                 {}
#             ).addTo(map_b6697e9c9b9ae7e126f05a799f07b7fc);
#
#
#         var popup_32cdcb939dd9da26c11930fba1c225ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5698cb0a6b74df4e6fa5fc4d34455f5c = $(`&lt;div id=&quot;html_5698cb0a6b74df4e6fa5fc4d34455f5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#             popup_32cdcb939dd9da26c11930fba1c225ca.setContent(html_5698cb0a6b74df4e6fa5fc4d34455f5c);
#
#
#         marker_5ef6a2008016d8e0183579c10da04437.bindPopup(popup_32cdcb939dd9da26c11930fba1c225ca)
#         ;
#
#
#
#
#             var marker_a10981513749d9dcc7aea2cbb9d7a0c5 = L.marker(
#                 [40.79264, -73.93898],
#                 {}
#             ).addTo(map_b6697e9c9b9ae7e126f05a799f07b7fc);
#
#
#         var popup_93bb68acbfd30ed755c9ae18a34df689 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dc7ef2f4bee8ea8b74b6d3a43c8ea4b7 = $(`&lt;div id=&quot;html_dc7ef2f4bee8ea8b74b6d3a43c8ea4b7&quot; style=&quot;width: 100.0%; hei

# %% [markdown]
# ## Show in a map the 10 lowest prices for each region

# %%
cols = ['neighbourhood_group', 'latitude', 'longitude', 'price']

data_map = data.loc[data['price'] > 0, cols].sort_values(['neighbourhood_group', 'price']).groupby('neighbourhood_group').head(10).reset_index(drop=True)
data_map
# Out:
#    neighbourhood_group  latitude  longitude  price
# 0                Bronx     40.83     -73.93     10
# 1                Bronx     40.84     -73.83     20
# 2                Bronx     40.85     -73.91     20
# 3                Bronx     40.84     -73.87     20
# 4                Bronx     40.84     -73.87     20
# 5                Bronx     40.84     -73.87     20
# 6                Bronx     40.86     -73.85     20
# 7                Bronx     40.86     -73.88     21
# 8                Bronx     40.84     -73.92     22
# 9                Bronx     40.86     -73.90     22
# 10            Brooklyn     40.70     -73.92     10
# 11            Brooklyn     40.72     -73.95     10
# 12            Brooklyn     40.66     -73.99     10
# 13            Brooklyn     40.71     -73.96     10
# 14            Brooklyn     40.70     -73.95     10
# 15            Brooklyn     40.70     -73.92     10
# 16            Brooklyn     40.69     -73.92     11
# 17            Brooklyn     40.67     -73.94     12
# 18            Brooklyn     40.66     -73.94     15
# 19            Brooklyn     40.69     -73.91     15
# 20           Manhattan     40.73     -73.98     10
# 21           Manhattan     40.81     -73.95     10
# 22           Manhattan     40.72     -74.00     10
# 23           Manhattan     40.77     -73.95     10
# 24           Manhattan     40.76     -73.99     10
# 25           Manhattan     40.77     -73.98     10
# 26           Manhattan     40.74     -73.98     10
# 27           Manhattan     40.80     -73.96     11
# 28           Manhattan     40.71     -74.02     12
# 29           Manhattan     40.74     -74.00     12
# 30              Queens     40.69     -73.80     10
# 31              Queens     40.69     -73.80     10
# 32              Queens     40.69     -73.86     10
# 33              Queens     40.73     -73.90     11
# 34              Queens     40.74     -73.92     12
# 35              Queens     40.74     -73.87     15
# 36              Queens     40.75     -73.83     15
# 37              Queens     40.76     -73.87     16
# 38              Queens     40.74     -73.85     16
# 39              Queens     40.68     -73.80     19
# 40       Staten Island     40.63     -74.13     13
# 41       Staten Island     40.62     -74.17     20
# 42       Staten Island     40.59     -74.10     20
# 43       Staten Island     40.63     -74.13     22
# 44       Staten Island     40.60     -74.17     25
# 45       Staten Island     40.63     -74.13     27
# 46       Staten Island     40.65     -74.08     29
# 47       Staten Island     40.60     -74.09     29
# 48       Staten Island     40.58     -74.11     29
# 49       Staten Island     40.63     -74.08     30

# %%
map = folium.Map(location = [40.712776, -74.005974], zoom_start=11)

for i, c in data_map.iterrows():
    folium.Marker(  [c['latitude'], c['longitude']],
                    popup=c['neighbourhood_group']).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_782bbddf14472a9ad4a7c1223b053af8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_782bbddf14472a9ad4a7c1223b053af8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_782bbddf14472a9ad4a7c1223b053af8 = L.map(
#                 &quot;map_782bbddf14472a9ad4a7c1223b053af8&quot;,
#                 {
#                     center: [40.712776, -74.005974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_578fddd5b9f56de1e61d8f79e7a1cc9a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_782bbddf14472a9ad4a7c1223b053af8);
#
#
#             var marker_30ab466bd7da5675480c2e0fe7b91c79 = L.marker(
#                 [40.83454, -73.92751],
#                 {}
#             ).addTo(map_782bbddf14472a9ad4a7c1223b053af8);
#
#
#         var popup_e09d9e748223f00f4a637d5332ca83c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_03ecc069b51c463d854b7f8b9d2d941d = $(`&lt;div id=&quot;html_03ecc069b51c463d854b7f8b9d2d941d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#             popup_e09d9e748223f00f4a637d5332ca83c7.setContent(html_03ecc069b51c463d854b7f8b9d2d941d);
#
#
#         marker_30ab466bd7da5675480c2e0fe7b91c79.bindPopup(popup_e09d9e748223f00f4a637d5332ca83c7)
#         ;
#
#
#
#
#             var marker_5ad5464f331aa30c276e4b6353aa70b3 = L.marker(
#                 [40.84034, -73.83007],
#                 {}
#             ).addTo(map_782bbddf14472a9ad4a7c1223b053af8);
#
#
#         var popup_ed3cb52cffa424ae61f416388f38ad35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dc97daf8468b217801d3d1af8be18398 = $(`&lt;div id=&quot;html_dc97daf8468b217801d3d1af8be18398&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#             popup_ed3cb52cffa424ae61f416388f38ad35.setContent(html_dc97daf8468b217801d3d1af8be18398);
#
#
#         marker_5ad5464f331aa30c276e4b6353aa70b3.bindPopup(popup_ed3cb52cffa424ae61f416388f38ad35)
#         ;
#
#
#
#
#             var marker_234ab453dadce7a6abb74960459825e9 = L.marker(
#                 [40.84718, -73.91378],
#                 {}
#             ).addTo(map_782bbddf14472a9ad4a7c1223b053af8);
#
#
#         var popup_97df1a8af065f17f340ce8f78d52988d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e12cd94a5910aabdbb650734596e7c3c = $(`&lt;div id=&quot;html_e12cd94a5910aabdbb650734596e7c3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#             popup_97df1a8af065f17f340ce8f78d52988d.setContent(html_e12cd94a5910aabdbb650734596e7c3c);
#
#
#         marker_234ab453dadce7a6abb74960459825e9.bindPopup(popup_97df1a8af065f17f340ce8f78d52988d)
#         ;
#
#
#
#
#             var marker_4d11385cca9c8dc56355525aa8858744 = L.marker(
#                 [40.84047, -73.87127],
#                 {}
#             ).addTo(map_782bbddf14472a9ad4a7c1223b053af8);
#
#
#         var popup_5cfdd7f5141be17a24d8f894d90b863e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bd6e4ff63b53dcc7bf03d2107e850bdf = $(`&lt;div id=&quot;html_bd6e4ff63b53dcc7bf03d2107e850bdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#             popup_5cfdd7f5141be17a24d8f894d90b863e.setContent(html_bd6e4ff63b53dcc7bf03d2107e850bdf);
#
#
#         marker_4d11385cca9c8dc56355525aa8858744.bindPopup(popup_5cfdd7f5141be17a24d8f894d90b863e)
#         ;
#
#
#
#
#             var marker_debcbe98b5311a160c2677de88c9d78a = L.marker(
#                 [40.84119, -73.87049],
#                 {}
#             ).addTo(map_782bbddf14472a9ad4a7c1223b053af8);
#
#
#         var popup_700b71620f46f6fdc8f79cf6140a1dd3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8e0da7df30488000fb270136b9179cac = $(`&lt;div id=&quot;html_8e0da7df30488000fb270136b9179cac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#             popup_700b71620f46f6fdc8f79cf6140a1dd3.setContent(html_8e0da7df30488000fb270136b9179cac);
#
#
#         marker_debcbe98b5311a160c2677de88c9d78a.bindPopup(popup_700b71620f46f6fdc8f79cf6140a1dd3)
#         ;
#
#
#
#
#             var marker_4ba3797e05830a9128b66933e793bddb = L.marker(
#                 [40.84087, -73.8699],
#                 {}
#             ).addTo(map_782bbddf14472a9ad4a7c1223b053af8);
#
#
#         var popup_dd656fd73789d8d1ad6b203d9fff2bad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ef1c048ab9ec058cb7135a3c563912eb = $(`&lt;div id=&quot;html_ef1c048ab9ec058cb7135a3c563912eb&quot; style=&quot;width: 100.0%; height: 100.0%;&q

# %% [markdown]
# ## What is the average rent price for each region?

# %%
mean_price_region = data[['neighbourhood_group', 'price']].groupby('neighbourhood_group').mean().reset_index()
mean_price_region['price'] = np.round(mean_price_region['price'], 2)

px.bar(mean_price_region, x='neighbourhood_group', y='price', text_auto=True, title = 'Average rent price per region in USD')

# %% [markdown]
# ## What is the median rent price for each region?

# %%
median_price_region = data[['neighbourhood_group', 'price']].groupby('neighbourhood_group').median().reset_index()

px.bar(median_price_region, x='neighbourhood_group', y='price',  title= 'Median rent price per region in USD', text_auto=True)

# %% [markdown]
# ## What are the properties with the highest rent value and where are they located?

# %%
#data.loc[data['price'] == data['price'].max(), ['id', 'neighbourhood_group', 'neighbourhood', 'price']].reset_index(drop=True)
data[data['price'] == data['price'].max()][['id', 'neighbourhood_group', 'neighbourhood', 'price']].reset_index(drop=True)
# Out:
#          id neighbourhood_group    neighbourhood  price
# 0   7003697              Queens          Astoria  10000
# 1  13894339            Brooklyn       Greenpoint  10000
# 2  22436899           Manhattan  Upper West Side  10000

# %% [markdown]
# ## Show how many apartments has in each neighbourhood

# %%
print(data['neighbourhood_group'].unique())
#print(data[['neighbourhood_group', 'neighbourhood']].groupby('neighbourhood_group').count().sort_values('neighbourhood'))
data['neighbourhood_group'].value_counts(ascending=True)
# Out:
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# Staten Island      373
# Bronx             1091
# Queens            5666
# Brooklyn         20104
# Manhattan        21661
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# ## Show the average accommodation price for each neighbourhood

# %%
data[['neighbourhood_group', 'price']].groupby('neighbourhood_group').mean().reset_index().sort_values('price')
# Out:
#   neighbourhood_group  price
# 0               Bronx  87.50
# 3              Queens  99.52
# 4       Staten Island 114.81
# 1            Brooklyn 124.38
# 2           Manhattan 196.88

# %% [markdown]
# ## Show how many accommodations are in each neighbourhood

# %%
data[['neighbourhood_group', 'neighbourhood', 'id']].groupby(['neighbourhood_group', 'neighbourhood']).count()
# Out:
#                                    id
# neighbourhood_group neighbourhood
# Bronx               Allerton       42
#                     Baychester      7
#                     Belmont        24
#                     Bronxdale      19
#                     Castle Hill     9
# ...                                ..
# Staten Island       Tottenville     7
#                     West Brighton  18
#                     Westerleigh     2
#                     Willowbrook     1
#                     Woodrow         1
#
# [221 rows x 1 columns]

# %% [markdown]
# ## Make a csv file with the neighbourhood group and neighbourhoods with the count of the numbers of properties in each one

# %%
neighbourhoods = data[['neighbourhood_group', 'neighbourhood', 'id']].groupby(['neighbourhood_group', 'neighbourhood']).count().reset_index()
neighbourhoods.rename(columns={'id':'n_accommodation'}, inplace=True)

neighbourhoods.to_csv('datasets/ny_neighbourhoods.csv')
