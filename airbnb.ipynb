# %% [markdown]
# # Business problem

# %% [markdown]
# This study aims to make a exploratory data analysis for answer some business questions about Airbnb accommodations.

# %% [markdown]
# # Data Context

# %% [markdown]
# # 0.0 Imports

# %%
# Data manipulation
import pandas as pd
import numpy as np

from IPython.display import HTML

# Set float values to display only two decimals
pd.set_option('display.float_format', lambda x: '%.2f' % x)


# Data visualization
from matplotlib import pyplot as plt
import plotly.express as px
import seaborn as sns
import folium

# %% [markdown]
# # 0.1 Helper Functions

# %%
def jupyter_settings():
    # %matplotlib inline
    
    plt.style.use('bmh')
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 40
    
    display(HTML('<style>.container {width:100% !important;}</style>'))
    pd.options.display.max_columns = None
    pd.set_option('display.expand_frame_repr', False)
    
    sns.set()

jupyter_settings()
# Out:
# <style>.container {width:100% !important;}</style>

# %% [markdown]
# # 0.2 Reading the data

# %%
airbnb_nyc = pd.read_csv('datasets/airbnb_ny_2019.csv')

airbnb_nyc.head()
# Out:
#      id                                              name  host_id    host_name neighbourhood_group neighbourhood  latitude  longitude        room_type  price  minimum_nights  number_of_reviews last_review  reviews_per_month  calculated_host_listings_count  availability_365
# 0  2539                Clean & quiet apt home by the park     2787         John            Brooklyn    Kensington     40.65     -73.97     Private room    149               1                  9  2018-10-19               0.21                               6               365
# 1  2595                             Skylit Midtown Castle     2845     Jennifer           Manhattan       Midtown     40.75     -73.98  Entire home/apt    225               1                 45  2019-05-21               0.38                               2               355
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth           Manhattan        Harlem     40.81     -73.94     Private room    150               3                  0         NaN                NaN                               1               365
# 3  3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne            Brooklyn  Clinton Hill     40.69     -73.96  Entire home/apt     89               1                270  2019-07-05               4.64                               1               194
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura           Manhattan   East Harlem     40.80     -73.94  Entire home/apt     80              10                  9  2018-11-19               0.10                               1                 0

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Checking the columns in the dataset

# %%
print(f'The columns of the dataset are: \n {airbnb_nyc.columns.tolist()}' )
# Out:
# The columns of the dataset are:
#  ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# %% [markdown]
# ## Data description

# %% [markdown]
# ### Rows, columns and data types

# %%
print(f' The dataset contains {airbnb_nyc.shape[0]} rows and {airbnb_nyc.shape[1]} columns' )
print('\n')
print(f'The types of the columns are: \n {airbnb_nyc.dtypes}')
# Out:
#  The dataset contains 48895 rows and 16 columns
#
#
# The types of the columns are:
#  id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# ## Transforming the data type of column 'last_review' from object to datetime

# %%
airbnb_nyc['last_review'] = pd.to_datetime(airbnb_nyc['last_review'], format = '%Y-%m-%d')

airbnb_nyc['last_review'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## Checking missing values

# %%
airbnb_nyc.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ## Descriptive Statistics

# %%
num_attributes = airbnb_nyc.select_dtypes(include = ['float64', 'int64'])
num_attributes
# Out:
#              id   host_id  latitude  longitude  price  minimum_nights  number_of_reviews  reviews_per_month  calculated_host_listings_count  availability_365
# 0          2539      2787     40.65     -73.97    149               1                  9               0.21                               6               365
# 1          2595      2845     40.75     -73.98    225               1                 45               0.38                               2               355
# 2          3647      4632     40.81     -73.94    150               3                  0                NaN                               1               365
# 3          3831      4869     40.69     -73.96     89               1                270               4.64                               1               194
# 4          5022      7192     40.80     -73.94     80              10                  9               0.10                               1                 0
# ...         ...       ...       ...        ...    ...             ...                ...                ...                             ...               ...
# 48890  36484665   8232441     40.68     -73.95     70               2                  0                NaN                               2                 9
# 48891  36485057   6570630     40.70     -73.93     40               4                  0                NaN                               2                36
# 48892  36485431  23492952     40.81     -73.95    115              10                  0                NaN                               1                27
# 48893  36485609  30985759     40.76     -73.99     55               1                  0                NaN                               6                 2
# 48894  36487245  68119814     40.76     -73.99     90               7                  0                NaN                               1                23
#
# [48895 rows x 10 columns]

# %%
num_attributes.drop(columns=['id', 'host_id', 'latitude', 'longitude'])
num_attributes.describe().transpose()
# Out:
#                                   count        mean         std     min        25%         50%          75%          max
# id                             48895.00 19017143.24 10983108.39 2539.00 9471945.00 19677284.00  29152178.50  36487245.00
# host_id                        48895.00 67620010.65 78610967.03 2438.00 7822033.00 30793816.00 107434423.00 274321313.00
# latitude                       48895.00       40.73        0.05   40.50      40.69       40.72        40.76        40.91
# longitude                      48895.00      -73.95        0.05  -74.24     -73.98      -73.96       -73.94       -73.71
# price                          48895.00      152.72      240.15    0.00      69.00      106.00       175.00     10000.00
# minimum_nights                 48895.00        7.03       20.51    1.00       1.00        3.00         5.00      1250.00
# number_of_reviews              48895.00       23.27       44.55    0.00       1.00        5.00        24.00       629.00
# reviews_per_month              38843.00        1.37        1.68    0.01       0.19        0.72         2.02        58.50
# calculated_host_listings_count 48895.00        7.14       32.95    1.00       1.00        1.00         2.00       327.00
# availability_365               48895.00      112.78      131.62    0.00       0.00       45.00       227.00       365.00

# %% [markdown]
# # Business Questions

# %% [markdown]
# ## What are the different accommodations types offered by the hosts?

# %%
accommodation = airbnb_nyc['room_type'].unique()

print(f' The different accommodations are {accommodation[0]}, {accommodation[1]} and {accommodation[2]}')
# Out:
#  The different accommodations are Private room, Entire home/apt and Shared room

# %% [markdown]
# ## How many hosts we have in the database?

# %%
unique_host = len(airbnb_nyc['host_id'].unique())

print(f' The are {unique_host} unique hosts in the database')
# Out:
#  The are 37457 unique hosts in the database

# %% [markdown]
# ## How is the price variation of accommodations in New York City?

# %%
# Calculate the standard deviation for the price column

price_std = np.round(airbnb_nyc['price'].std(), 2)
price_mean = np.round(airbnb_nyc['price'].mean(), 2)

print(f' The price variation in NYC is U${price_std}, what indicates a wide price range, since the mean price is U${price_mean}')
# Out:
#  The price variation in NYC is U$240.15, what indicates a wide price range, since the mean price is U$152.72

# %% [markdown]
# ## What is the price distribution? There are more cheap or expensive accommodations?

# %%
#plt.figure(figsize = (20,5))
#plt.hist(airbnb_nyc['price'], bins=100);

px.histogram(airbnb_nyc[airbnb_nyc['price'] < 2000], 'price', nbins=50 )

# %%
print('There are more properties listing with low cost rent and a few with high cost, as the histogram shows us.')
# Out:
# There are more properties listing with low cost rent and a few with high cost, as the histogram shows us.

# %% [markdown]
# ## What is the highest price among accommodations avaiable to rent per region?

# %%
available_true = airbnb_nyc[airbnb_nyc['availability_365'] > 0]
data_plot = available_true[['neighbourhood_group', 'price']].groupby('neighbourhood_group').max().reset_index()

px.bar(data_plot, x='neighbourhood_group', y='price', title= 'Max rent price per region', text_auto=True)

# %% [markdown]
# ## Can we know where these accomodations are?

# %%
cols = ['neighbourhood_group', 'price', 'latitude', 'longitude' ]

neighbourhood_max = available_true.loc[:, cols].groupby('neighbourhood_group').max().reset_index()

neighbourhood_max
# Out:
#   neighbourhood_group  price  latitude  longitude
# 0               Bronx   2500     40.91     -73.78
# 1            Brooklyn   8000     40.74     -73.86
# 2           Manhattan  10000     40.88     -73.91
# 3              Queens   2600     40.80     -73.71
# 4       Staten Island   5000     40.65     -74.06

# %%
map = folium.Map(location = [40.712776, -74.005974], zoom_start=11)

for i, c in neighbourhood_max.iterrows():
    folium.Marker([c['latitude'], c['longitude']]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f14202b425ff2654770174837252cdb9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f14202b425ff2654770174837252cdb9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f14202b425ff2654770174837252cdb9 = L.map(
#                 &quot;map_f14202b425ff2654770174837252cdb9&quot;,
#                 {
#                     center: [40.712776, -74.005974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da4841ca859ab81c65ada78da0fb3a10 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f14202b425ff2654770174837252cdb9);
#
#
#             var marker_bf799a5513780bbdd5e2a89e222bd8fb = L.marker(
#                 [40.91306, -73.78158],
#                 {}
#             ).addTo(map_f14202b425ff2654770174837252cdb9);
#
#
#             var marker_d2d72d9df9b52f5b9510169cfcc48731 = L.marker(
#                 [40.7389, -73.85676],
#                 {}
#             ).addTo(map_f14202b425ff2654770174837252cdb9);
#
#
#             var marker_898c632773c95c5080578019dbd0a57e = L.marker(
#                 [40.87665, -73.90855],
#                 {}
#             ).addTo(map_f14202b425ff2654770174837252cdb9);
#
#
#             var marker_c0db2fcbc900205e48d5c550b62717a8 = L.marker(
#                 [40.79721, -73.71299],
#                 {}
#             ).addTo(map_f14202b425ff2654770174837252cdb9);
#
#
#             var marker_716dc71a15f23053ff09db46263ae740 = L.marker(
#                 [40.64779, -74.06092],
#                 {}
#             ).addTo(map_f14202b425ff2654770174837252cdb9);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Can we identify the accommodations in a map by color indicating their room type?

# %%
cols = ['neighbourhood_group', 'room_type', 'latitude', 'longitude' ]

roomtype_color = airbnb_nyc.loc[:, cols].sample( 100 )

roomtype_color['color'] = 'NA'

roomtype_color.loc[roomtype_color['room_type'] == 'Private room', 'color' ] = 'darkgreen'
roomtype_color.loc[roomtype_color['room_type'] == 'Entire home/apt', 'color' ] = 'darkred'
roomtype_color.loc[roomtype_color['room_type'] == 'Shared room', 'color' ] = 'darkblue'

roomtype_color
# Out:
#       neighbourhood_group        room_type  latitude  longitude      color
# 17002            Brooklyn     Private room     40.69     -73.97  darkgreen
# 298              Brooklyn     Private room     40.73     -73.96  darkgreen
# 24159              Queens     Private room     40.73     -73.85  darkgreen
# 38492       Staten Island  Entire home/apt     40.59     -74.16    darkred
# 20576            Brooklyn  Entire home/apt     40.68     -73.95    darkred
# ...                   ...              ...       ...        ...        ...
# 36269           Manhattan  Entire home/apt     40.85     -73.94    darkred
# 27871            Brooklyn  Entire home/apt     40.69     -73.93    darkred
# 46918           Manhattan  Entire home/apt     40.77     -73.99    darkred
# 42488            Brooklyn     Private room     40.70     -73.95  darkgreen
# 38337            Brooklyn     Private room     40.66     -73.93  darkgreen
#
# [100 rows x 5 columns]

# %%
map = folium.Map(location = [40.712776, -74.005974], zoom_start=11)

for i, c in roomtype_color.iterrows():
    folium.Marker(  [c['latitude'], c['longitude']],
                    popup=c['room_type'],
                    icon=folium.Icon(color = c['color'])).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0798e6157c3592138eccfd540f925e8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0798e6157c3592138eccfd540f925e8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0798e6157c3592138eccfd540f925e8f = L.map(
#                 &quot;map_0798e6157c3592138eccfd540f925e8f&quot;,
#                 {
#                     center: [40.712776, -74.005974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4aade985c0621d11d038d8cba6ddbdb3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0798e6157c3592138eccfd540f925e8f);
#
#
#             var marker_ef096d2cc60adbc628d2ec222ea6264c = L.marker(
#                 [40.69288, -73.96592],
#                 {}
#             ).addTo(map_0798e6157c3592138eccfd540f925e8f);
#
#
#             var icon_df3486f088c63aa1817067552974a1ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ef096d2cc60adbc628d2ec222ea6264c.setIcon(icon_df3486f088c63aa1817067552974a1ed);
#
#
#         var popup_94e248323bc9129e2b995b5213ba2832 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8627c5ebe507c80913cfdba4c84da7db = $(`&lt;div id=&quot;html_8627c5ebe507c80913cfdba4c84da7db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Private room&lt;/div&gt;`)[0];
#             popup_94e248323bc9129e2b995b5213ba2832.setContent(html_8627c5ebe507c80913cfdba4c84da7db);
#
#
#         marker_ef096d2cc60adbc628d2ec222ea6264c.bindPopup(popup_94e248323bc9129e2b995b5213ba2832)
#         ;
#
#
#
#
#             var marker_3460044a373f2b649398fbea226fddfa = L.marker(
#                 [40.73119, -73.95578],
#                 {}
#             ).addTo(map_0798e6157c3592138eccfd540f925e8f);
#
#
#             var icon_5d587f7602b74cc05c5d0e150018e787 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3460044a373f2b649398fbea226fddfa.setIcon(icon_5d587f7602b74cc05c5d0e150018e787);
#
#
#         var popup_6fc1ed895c63ab5418e22947348421f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ddee1f0afdfafd3b40b70fd24f19ea16 = $(`&lt;div id=&quot;html_ddee1f0afdfafd3b40b70fd24f19ea16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Private room&lt;/div&gt;`)[0];
#             popup_6fc1ed895c63ab5418e22947348421f5.setContent(html_ddee1f0afdfafd3b40b70fd24f19ea16);
#
#
#         marker_3460044a373f2b649398fbea226fddfa.bindPopup(popup_6fc1ed895c63ab5418e22947348421f5)
#         ;
#
#
#
#
#             var marker_17367f4ea20d588bc5f9a85952983736 = L.marker(
#                 [40.73321, -73.85058],
#                 {}
#             ).addTo(map_0798e6157c3592138eccfd540f925e8f);
#
#
#             var icon_f19b9c2b3ddf4e935f1c1a509cefeec3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_17367f4ea20d588bc5f9a85952983736.setIcon(icon_f19b9c2b3ddf4e935f1c1a509cefeec3);
#
#
#         var popup_c1c8b097d2a4e5bc675cd148d8613ca7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ffaa4d439512fba78ee5d34b7134f54e = $(`&lt;div id=&quot;html_ffaa4d439512fba78ee5d34b7134f54e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Private room&lt;/div&gt;`)[0];
#             popup_c1c8b097d2a4e5bc675cd148d8613ca7.setContent(html_ffaa4d439512fba78ee5d34b7134f54e);
#
#
#         marker_17367f4ea20d588bc5f9a85952983736.bindPopup(popup_c1c8b097d2a4e5bc675cd148d8613ca7)
#         ;
#
#
#
#
#             var marker_bfb79b3856b7db02becc0bbc463d9649 = L.marker(
#                 [40.58952, -74.15587],
#                 {}
#             ).addTo(map_0798e6157c3592138eccfd540f925e8f);
#
#
#             var icon_e666cea02bb7c7485edce73d168a2bae = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bfb79b3856b7db02becc0bbc463d9649.setIcon(icon_e666c

# %% [markdown]
# ## What are the top 10 reviews accommodations by region?

# %%
cols = ['neighbourhood_group', 'latitude', 'longitude', 'number_of_reviews']

region_top10_review = airbnb_nyc.loc[:, cols].sort_values('number_of_reviews', ascending=False).groupby('neighbourhood_group').head(10).reset_index(drop=True)
region_top10_review.sort_values(['neighbourhood_group', 'number_of_reviews'], ascending=[True, False]).reset_index(drop=True)
# Out:
#    neighbourhood_group  latitude  longitude  number_of_reviews
# 0                Bronx     40.81     -73.92                321
# 1                Bronx     40.84     -73.91                291
# 2                Bronx     40.81     -73.93                276
# 3                Bronx     40.86     -73.86                271
# 4                Bronx     40.83     -73.83                266
# 5                Bronx     40.83     -73.92                258
# 6                Bronx     40.83     -73.92                235
# 7                Bronx     40.81     -73.92                231
# 8                Bronx     40.85     -73.78                227
# 9                Bronx     40.83     -73.93                219
# 10            Brooklyn     40.68     -73.98                488
# 11            Brooklyn     40.70     -73.92                480
# 12            Brooklyn     40.67     -73.99                467
# 13            Brooklyn     40.69     -73.96                426
# 14            Brooklyn     40.71     -73.96                404
# 15            Brooklyn     40.66     -73.96                401
# 16            Brooklyn     40.67     -73.99                398
# 17            Brooklyn     40.69     -73.94                397
# 18            Brooklyn     40.71     -73.94                385
# 19            Brooklyn     40.67     -73.99                378
# 20           Manhattan     40.82     -73.94                607
# 21           Manhattan     40.82     -73.94                597
# 22           Manhattan     40.82     -73.94                594
# 23           Manhattan     40.72     -73.99                540
# 24           Manhattan     40.83     -73.94                458
# 25           Manhattan     40.73     -73.98                451
# 26           Manhattan     40.72     -74.00                447
# 27           Manhattan     40.83     -73.94                439
# 28           Manhattan     40.76     -73.98                430
# 29           Manhattan     40.73     -73.98                414
# 30              Queens     40.67     -73.77                629
# 31              Queens     40.67     -73.77                576
# 32              Queens     40.77     -73.88                543
# 33              Queens     40.76     -73.87                510
# 34              Queens     40.76     -73.82                474
# 35              Queens     40.77     -73.88                466
# 36              Queens     40.77     -73.88                459
# 37              Queens     40.68     -73.76                454
# 38              Queens     40.77     -73.88                448
# 39              Queens     40.75     -73.91                441
# 40       Staten Island     40.63     -74.09                333
# 41       Staten Island     40.62     -74.07                242
# 42       Staten Island     40.64     -74.08                234
# 43       Staten Island     40.63     -74.12                196
# 44       Staten Island     40.64     -74.09                193
# 45       Staten Island     40.63     -74.08                177
# 46       Staten Island     40.64     -74.09                177
# 47       Staten Island     40.65     -74.08                166
# 48       Staten Island     40.64     -74.08                157
# 49       Staten Island     40.62     -74.09                151

# %%
map = folium.Map(location = [40.712776, -74.005974], zoom_start=11)

for i, c in region_top10_review.iterrows():
    folium.Marker(  [c['latitude'], c['longitude']],
                    popup=c['neighbourhood_group']).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d55dfc9adb84fecfaf43ce113792302c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d55dfc9adb84fecfaf43ce113792302c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d55dfc9adb84fecfaf43ce113792302c = L.map(
#                 &quot;map_d55dfc9adb84fecfaf43ce113792302c&quot;,
#                 {
#                     center: [40.712776, -74.005974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3cad282f21e83bf2b846e2a4a3cb2951 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d55dfc9adb84fecfaf43ce113792302c);
#
#
#             var marker_cd12c69fa5434f122440e9842ca60feb = L.marker(
#                 [40.6673, -73.76831],
#                 {}
#             ).addTo(map_d55dfc9adb84fecfaf43ce113792302c);
#
#
#         var popup_d0e8363cc1f0cdfaa76ee8a4a4e47749 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c56ae6c052b326404803e71d857c490b = $(`&lt;div id=&quot;html_c56ae6c052b326404803e71d857c490b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Queens&lt;/div&gt;`)[0];
#             popup_d0e8363cc1f0cdfaa76ee8a4a4e47749.setContent(html_c56ae6c052b326404803e71d857c490b);
#
#
#         marker_cd12c69fa5434f122440e9842ca60feb.bindPopup(popup_d0e8363cc1f0cdfaa76ee8a4a4e47749)
#         ;
#
#
#
#
#             var marker_c73d6a29f63210f2e00a82a1910c99af = L.marker(
#                 [40.82085, -73.94025],
#                 {}
#             ).addTo(map_d55dfc9adb84fecfaf43ce113792302c);
#
#
#         var popup_e72af229ec66330922411481794c8054 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fffd3a7f5e6ab0251a3ebc096820952a = $(`&lt;div id=&quot;html_fffd3a7f5e6ab0251a3ebc096820952a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#             popup_e72af229ec66330922411481794c8054.setContent(html_fffd3a7f5e6ab0251a3ebc096820952a);
#
#
#         marker_c73d6a29f63210f2e00a82a1910c99af.bindPopup(popup_e72af229ec66330922411481794c8054)
#         ;
#
#
#
#
#             var marker_2e6b2e44e836aaf848ff224fe038ec27 = L.marker(
#                 [40.82124, -73.93838],
#                 {}
#             ).addTo(map_d55dfc9adb84fecfaf43ce113792302c);
#
#
#         var popup_7794adc30c203eb4211d302204aef1e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f62eee31e347b49c5d85ff44b6c6902d = $(`&lt;div id=&quot;html_f62eee31e347b49c5d85ff44b6c6902d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#             popup_7794adc30c203eb4211d302204aef1e2.setContent(html_f62eee31e347b49c5d85ff44b6c6902d);
#
#
#         marker_2e6b2e44e836aaf848ff224fe038ec27.bindPopup(popup_7794adc30c203eb4211d302204aef1e2)
#         ;
#
#
#
#
#             var marker_d98e7a6dd7566e19b8d0172cd8429d0e = L.marker(
#                 [40.82264, -73.94041],
#                 {}
#             ).addTo(map_d55dfc9adb84fecfaf43ce113792302c);
#
#
#         var popup_6147b89001017be336fb096946fc173c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7b08df1aab4b2e0a2e56c49f56d651d4 = $(`&lt;div id=&quot;html_7b08df1aab4b2e0a2e56c49f56d651d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#             popup_6147b89001017be336fb096946fc173c.setContent(html_7b08df1aab4b2e0a2e56c49f56d651d4);
#
#
#         marker_d98e7a6dd7566e19b8d0172cd8429d0e.bindPopup(popup_6147b89001017be336fb096946fc173c)
#         ;
#
#
#
#
#             var marker_e13a9acf90a26c6fa5244a272f07ceba = L.marker(
#                 [40.66939, -73.76975],
#                 {}
#             ).addTo(map_d55dfc9adb84fecfaf43ce113792302c);
#
#
#         var popup_481bd0365922aa0b298612c6617bdbce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7369faebaf71ddb83fff93218ad624f6 = $(`&lt;div id=&quot;html_7369faebaf71ddb83fff93218ad624f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Queens&lt;/div&gt;`)[0];
#             popup_481bd0365922aa0b298612c6617bdbce.setContent(html_7369faebaf71ddb83fff93218ad624f6);
#
#
#         marker_e13a9acf90a26c6fa5244a272f07ceba.bindPopup(popup_481bd0365922aa0b298612c6617bdbce)
#         ;
#
#
#
#
#             var marker_626fe65d87cb4409efade142e5910a66 = L.marker(
#                 [40.77006, -73.87683],
#                 {}
#             ).addTo(map_d55dfc9adb84fecfaf43ce113792302c);
#
#
#         var popup_1aafe06bc732547105fc63e6b103f83b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_88efec9764465416f3cbfa6c178086bf = $(`&lt;div id=&quot;html_88efec9764465416f3cbfa6c178086bf&quot; style=&quot;width: 100.0%; hei

# %% [markdown]
# ## What are the top 50 highest prices?

# %%
cols = ['neighbourhood_group', 'latitude', 'longitude', 'price']

top50_high_price = airbnb_nyc.loc[:, cols].sort_values('price', ascending=False).head(50).reset_index(drop=True)
top50_high_price.sort_values('price', ascending=False)
# Out:
#    neighbourhood_group  latitude  longitude  price
# 0               Queens     40.77     -73.92  10000
# 1             Brooklyn     40.73     -73.96  10000
# 2            Manhattan     40.77     -73.99  10000
# 3            Manhattan     40.72     -73.99   9999
# 4            Manhattan     40.71     -73.99   9999
# 5            Manhattan     40.79     -73.94   9999
# 6            Manhattan     40.72     -74.01   8500
# 7             Brooklyn     40.69     -73.97   8000
# 8            Manhattan     40.77     -73.96   7703
# 9            Manhattan     40.71     -74.02   7500
# 10            Brooklyn     40.66     -73.92   7500
# 11           Manhattan     40.75     -74.00   6800
# 12           Manhattan     40.77     -73.98   6500
# 13            Brooklyn     40.69     -73.96   6500
# 14           Manhattan     40.71     -74.01   6500
# 15           Manhattan     40.79     -73.95   6419
# 16           Manhattan     40.78     -73.98   6000
# 17           Manhattan     40.73     -74.00   6000
# 18           Manhattan     40.72     -74.00   5250
# 19           Manhattan     40.74     -73.98   5100
# 23            Brooklyn     40.68     -73.88   5000
# 24           Manhattan     40.72     -73.99   5000
# 25            Brooklyn     40.70     -73.96   5000
# 22           Manhattan     40.83     -73.95   5000
# 21            Brooklyn     40.69     -73.92   5000
# 20       Staten Island     40.64     -74.10   5000
# 26            Brooklyn     40.72     -73.96   4500
# 27            Brooklyn     40.69     -73.97   4500
# 28            Brooklyn     40.69     -73.95   4200
# 29            Brooklyn     40.63     -74.02   4200
# 30           Manhattan     40.75     -74.00   4160
# 31           Manhattan     40.76     -73.99   4100
# 32           Manhattan     40.74     -74.01   4000
# 33           Manhattan     40.79     -73.97   4000
# 34            Brooklyn     40.68     -73.97   4000
# 35           Manhattan     40.73     -73.99   3900
# 36           Manhattan     40.73     -73.99   3800
# 37           Manhattan     40.73     -73.99   3750
# 38           Manhattan     40.71     -74.02   3750
# 39           Manhattan     40.79     -73.97   3613
# 40           Manhattan     40.77     -73.97   3600
# 41           Manhattan     40.73     -73.99   3518
# 42           Manhattan     40.79     -73.97   3512
# 43           Manhattan     40.75     -74.00   3210
# 44           Manhattan     40.81     -73.95   3200
# 45           Manhattan     40.74     -73.99   3000
# 46           Manhattan     40.76     -73.99   3000
# 47           Manhattan     40.78     -73.98   3000
# 48           Manhattan     40.73     -74.01   3000
# 49           Manhattan     40.80     -73.97   3000

# %%
map = folium.Map(location = [40.712776, -74.005974], zoom_start=11)

for i, c in top50_high_price.iterrows():
    folium.Marker(  [c['latitude'], c['longitude']],
                    popup=c['neighbourhood_group']).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6863c29b56cf2d44de5db33cebbed1c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6863c29b56cf2d44de5db33cebbed1c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6863c29b56cf2d44de5db33cebbed1c1 = L.map(
#                 &quot;map_6863c29b56cf2d44de5db33cebbed1c1&quot;,
#                 {
#                     center: [40.712776, -74.005974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f6efeadc7d8f671ab00064f4929f424 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6863c29b56cf2d44de5db33cebbed1c1);
#
#
#             var marker_1e8978a1a3683fbe8952b127e6865d96 = L.marker(
#                 [40.7681, -73.91651],
#                 {}
#             ).addTo(map_6863c29b56cf2d44de5db33cebbed1c1);
#
#
#         var popup_8e56d0e4c06df87e2904076f37e98d16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_06e2976f373f28b82aa3dd8890ebd35d = $(`&lt;div id=&quot;html_06e2976f373f28b82aa3dd8890ebd35d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Queens&lt;/div&gt;`)[0];
#             popup_8e56d0e4c06df87e2904076f37e98d16.setContent(html_06e2976f373f28b82aa3dd8890ebd35d);
#
#
#         marker_1e8978a1a3683fbe8952b127e6865d96.bindPopup(popup_8e56d0e4c06df87e2904076f37e98d16)
#         ;
#
#
#
#
#             var marker_494547c949d92c6488ac857dcbe5ff3d = L.marker(
#                 [40.7326, -73.95739],
#                 {}
#             ).addTo(map_6863c29b56cf2d44de5db33cebbed1c1);
#
#
#         var popup_3fe3f92a34bd910c2d168b877b23e6a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b2f14e1d18d5d9eaa43a3623179025a2 = $(`&lt;div id=&quot;html_b2f14e1d18d5d9eaa43a3623179025a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brooklyn&lt;/div&gt;`)[0];
#             popup_3fe3f92a34bd910c2d168b877b23e6a8.setContent(html_b2f14e1d18d5d9eaa43a3623179025a2);
#
#
#         marker_494547c949d92c6488ac857dcbe5ff3d.bindPopup(popup_3fe3f92a34bd910c2d168b877b23e6a8)
#         ;
#
#
#
#
#             var marker_3be4e3fab318fc586580463a8d74902a = L.marker(
#                 [40.77213, -73.98665],
#                 {}
#             ).addTo(map_6863c29b56cf2d44de5db33cebbed1c1);
#
#
#         var popup_acb157f4270943eca62124ebb5443187 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e9359ad32c44185d6291d002ed994cd6 = $(`&lt;div id=&quot;html_e9359ad32c44185d6291d002ed994cd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#             popup_acb157f4270943eca62124ebb5443187.setContent(html_e9359ad32c44185d6291d002ed994cd6);
#
#
#         marker_3be4e3fab318fc586580463a8d74902a.bindPopup(popup_acb157f4270943eca62124ebb5443187)
#         ;
#
#
#
#
#             var marker_14cdf9e1180df915fe4bb643c94e63d1 = L.marker(
#                 [40.7198, -73.98566],
#                 {}
#             ).addTo(map_6863c29b56cf2d44de5db33cebbed1c1);
#
#
#         var popup_a5c7dcc1ad79b6ccc124fc1122394a63 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9070eaa0cd5861df0665085f9a31c19d = $(`&lt;div id=&quot;html_9070eaa0cd5861df0665085f9a31c19d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#             popup_a5c7dcc1ad79b6ccc124fc1122394a63.setContent(html_9070eaa0cd5861df0665085f9a31c19d);
#
#
#         marker_14cdf9e1180df915fe4bb643c94e63d1.bindPopup(popup_a5c7dcc1ad79b6ccc124fc1122394a63)
#         ;
#
#
#
#
#             var marker_3448dc18d49bf980fe5d56350f4f09f5 = L.marker(
#                 [40.71355, -73.98507],
#                 {}
#             ).addTo(map_6863c29b56cf2d44de5db33cebbed1c1);
#
#
#         var popup_fab281bea015ad9f47c5ca68209f9a8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ab6ec1cbfb92f8413e0abad8865beb06 = $(`&lt;div id=&quot;html_ab6ec1cbfb92f8413e0abad8865beb06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#             popup_fab281bea015ad9f47c5ca68209f9a8b.setContent(html_ab6ec1cbfb92f8413e0abad8865beb06);
#
#
#         marker_3448dc18d49bf980fe5d56350f4f09f5.bindPopup(popup_fab281bea015ad9f47c5ca68209f9a8b)
#         ;
#
#
#
#
#             var marker_aec5aa21481ccd6736c1af49d6bf1606 = L.marker(
#                 [40.79264, -73.93898],
#                 {}
#             ).addTo(map_6863c29b56cf2d44de5db33cebbed1c1);
#
#
#         var popup_a6d1802b3fc35d30609bbe3017b2aca8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_605ddb1e53de4c85f9e887e09904f37f = $(`&lt;div id=&quot;html_605ddb1e53de4c85f9e887e09904f37f&quot; style=&quot;width: 100.0%; hei

# %% [markdown]
# ## Show in a map the 10 lowest prices for each region

# %%
cols = ['neighbourhood_group', 'latitude', 'longitude', 'price']

region_bottom10_price = airbnb_nyc.loc[airbnb_nyc['price'] > 0, cols].sort_values(['neighbourhood_group', 'price']).groupby('neighbourhood_group').head(10).reset_index(drop=True)
region_bottom10_price
# Out:
#    neighbourhood_group  latitude  longitude  price
# 0                Bronx     40.83     -73.93     10
# 1                Bronx     40.84     -73.83     20
# 2                Bronx     40.85     -73.91     20
# 3                Bronx     40.84     -73.87     20
# 4                Bronx     40.84     -73.87     20
# 5                Bronx     40.84     -73.87     20
# 6                Bronx     40.86     -73.85     20
# 7                Bronx     40.86     -73.88     21
# 8                Bronx     40.84     -73.92     22
# 9                Bronx     40.86     -73.90     22
# 10            Brooklyn     40.70     -73.92     10
# 11            Brooklyn     40.72     -73.95     10
# 12            Brooklyn     40.66     -73.99     10
# 13            Brooklyn     40.71     -73.96     10
# 14            Brooklyn     40.70     -73.95     10
# 15            Brooklyn     40.70     -73.92     10
# 16            Brooklyn     40.69     -73.92     11
# 17            Brooklyn     40.67     -73.94     12
# 18            Brooklyn     40.66     -73.94     15
# 19            Brooklyn     40.69     -73.91     15
# 20           Manhattan     40.73     -73.98     10
# 21           Manhattan     40.81     -73.95     10
# 22           Manhattan     40.72     -74.00     10
# 23           Manhattan     40.77     -73.95     10
# 24           Manhattan     40.76     -73.99     10
# 25           Manhattan     40.77     -73.98     10
# 26           Manhattan     40.74     -73.98     10
# 27           Manhattan     40.80     -73.96     11
# 28           Manhattan     40.71     -74.02     12
# 29           Manhattan     40.74     -74.00     12
# 30              Queens     40.69     -73.80     10
# 31              Queens     40.69     -73.80     10
# 32              Queens     40.69     -73.86     10
# 33              Queens     40.73     -73.90     11
# 34              Queens     40.74     -73.92     12
# 35              Queens     40.74     -73.87     15
# 36              Queens     40.75     -73.83     15
# 37              Queens     40.76     -73.87     16
# 38              Queens     40.74     -73.85     16
# 39              Queens     40.68     -73.80     19
# 40       Staten Island     40.63     -74.13     13
# 41       Staten Island     40.62     -74.17     20
# 42       Staten Island     40.59     -74.10     20
# 43       Staten Island     40.63     -74.13     22
# 44       Staten Island     40.60     -74.17     25
# 45       Staten Island     40.63     -74.13     27
# 46       Staten Island     40.65     -74.08     29
# 47       Staten Island     40.60     -74.09     29
# 48       Staten Island     40.58     -74.11     29
# 49       Staten Island     40.63     -74.08     30

# %%
map = folium.Map(location = [40.712776, -74.005974], zoom_start=11)

for i, c in region_bottom10_price.iterrows():
    folium.Marker(  [c['latitude'], c['longitude']],
                    popup=c['neighbourhood_group']).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3eb0e64e24c317bb63bd57c2cc82cc42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3eb0e64e24c317bb63bd57c2cc82cc42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3eb0e64e24c317bb63bd57c2cc82cc42 = L.map(
#                 &quot;map_3eb0e64e24c317bb63bd57c2cc82cc42&quot;,
#                 {
#                     center: [40.712776, -74.005974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10852b8aecbbe3743823b64c0ab74e4e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3eb0e64e24c317bb63bd57c2cc82cc42);
#
#
#             var marker_1380969e9b607fe8572d543c067d49ec = L.marker(
#                 [40.83454, -73.92751],
#                 {}
#             ).addTo(map_3eb0e64e24c317bb63bd57c2cc82cc42);
#
#
#         var popup_c2056ecade0125082260376793e41c26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5413d5cd56bfc072b38f77620f1ec16c = $(`&lt;div id=&quot;html_5413d5cd56bfc072b38f77620f1ec16c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#             popup_c2056ecade0125082260376793e41c26.setContent(html_5413d5cd56bfc072b38f77620f1ec16c);
#
#
#         marker_1380969e9b607fe8572d543c067d49ec.bindPopup(popup_c2056ecade0125082260376793e41c26)
#         ;
#
#
#
#
#             var marker_0b058ded6ac0b26410fe10fa65b65723 = L.marker(
#                 [40.84034, -73.83007],
#                 {}
#             ).addTo(map_3eb0e64e24c317bb63bd57c2cc82cc42);
#
#
#         var popup_812ee79c70c9ad7226f028a1ec7de9b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0f2b70e4ff9551e29cd877fc10cf8f1a = $(`&lt;div id=&quot;html_0f2b70e4ff9551e29cd877fc10cf8f1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#             popup_812ee79c70c9ad7226f028a1ec7de9b8.setContent(html_0f2b70e4ff9551e29cd877fc10cf8f1a);
#
#
#         marker_0b058ded6ac0b26410fe10fa65b65723.bindPopup(popup_812ee79c70c9ad7226f028a1ec7de9b8)
#         ;
#
#
#
#
#             var marker_d3e0999faff1d1e5d65f5ff23d2d320f = L.marker(
#                 [40.84718, -73.91378],
#                 {}
#             ).addTo(map_3eb0e64e24c317bb63bd57c2cc82cc42);
#
#
#         var popup_1f9b556edcfd86efbc71f2d5403cb006 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_068e646190051ac820e9ff2c06e707ba = $(`&lt;div id=&quot;html_068e646190051ac820e9ff2c06e707ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#             popup_1f9b556edcfd86efbc71f2d5403cb006.setContent(html_068e646190051ac820e9ff2c06e707ba);
#
#
#         marker_d3e0999faff1d1e5d65f5ff23d2d320f.bindPopup(popup_1f9b556edcfd86efbc71f2d5403cb006)
#         ;
#
#
#
#
#             var marker_3add9889328a46f6fda6e122df486f79 = L.marker(
#                 [40.84047, -73.87127],
#                 {}
#             ).addTo(map_3eb0e64e24c317bb63bd57c2cc82cc42);
#
#
#         var popup_06e547906ccf19224128600cd60c2b38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d261544bd2e23b98c55b2d1eb5845247 = $(`&lt;div id=&quot;html_d261544bd2e23b98c55b2d1eb5845247&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#             popup_06e547906ccf19224128600cd60c2b38.setContent(html_d261544bd2e23b98c55b2d1eb5845247);
#
#
#         marker_3add9889328a46f6fda6e122df486f79.bindPopup(popup_06e547906ccf19224128600cd60c2b38)
#         ;
#
#
#
#
#             var marker_fa2241e339567851e87986edd381ef42 = L.marker(
#                 [40.84119, -73.87049],
#                 {}
#             ).addTo(map_3eb0e64e24c317bb63bd57c2cc82cc42);
#
#
#         var popup_9bde06a00d0d0e3cc0444db46625c76f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d6e24b9410ccbd5267e3f17d1462dbf0 = $(`&lt;div id=&quot;html_d6e24b9410ccbd5267e3f17d1462dbf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronx&lt;/div&gt;`)[0];
#             popup_9bde06a00d0d0e3cc0444db46625c76f.setContent(html_d6e24b9410ccbd5267e3f17d1462dbf0);
#
#
#         marker_fa2241e339567851e87986edd381ef42.bindPopup(popup_9bde06a00d0d0e3cc0444db46625c76f)
#         ;
#
#
#
#
#             var marker_5118d2c91454949d8b7f873355453740 = L.marker(
#                 [40.84087, -73.8699],
#                 {}
#             ).addTo(map_3eb0e64e24c317bb63bd57c2cc82cc42);
#
#
#         var popup_72db6a57ddd9c0a7e60c89626df16717 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_00f0d894e653edd0842030192f483ab7 = $(`&lt;div id=&quot;html_00f0d894e653edd0842030192f483ab7&quot; style=&quot;width: 100.0%; height: 100.0%;&q

# %% [markdown]
# ## What is the average rent price for each region?

# %%
mean_price_region = airbnb_nyc[['neighbourhood_group', 'price']].groupby('neighbourhood_group').mean().reset_index()
mean_price_region['price'] = np.round(mean_price_region['price'], 2)

px.bar(mean_price_region, x='neighbourhood_group', y='price', text_auto=True, title = 'Average rent price per region in USD')

# %% [markdown]
# ## What is the median rent price for each region?

# %%
median_price_region = airbnb_nyc[['neighbourhood_group', 'price']].groupby('neighbourhood_group').median().reset_index()

px.bar(median_price_region, x='neighbourhood_group', y='price',  title= 'Median rent price per region in USD', text_auto=True)

# %% [markdown]
# ## What are the properties with the highest rent value and where are they located?

# %%
#airbnb_nyc.loc[airbnb_nyc['price'] == airbnb_nyc['price'].max(), ['id', 'neighbourhood_group', 'neighbourhood', 'price']].reset_index(drop=True)
airbnb_nyc[airbnb_nyc['price'] == airbnb_nyc['price'].max()][['id', 'neighbourhood_group', 'neighbourhood', 'price']].reset_index(drop=True)
# Out:
#          id neighbourhood_group    neighbourhood  price
# 0   7003697              Queens          Astoria  10000
# 1  13894339            Brooklyn       Greenpoint  10000
# 2  22436899           Manhattan  Upper West Side  10000

# %% [markdown]
# ## Show how many apartments has in each neighbourhood

# %%
print(airbnb_nyc['neighbourhood_group'].unique())
#print(airbnb_nyc[['neighbourhood_group', 'neighbourhood']].groupby('neighbourhood_group').count().sort_values('neighbourhood'))
airbnb_nyc['neighbourhood_group'].value_counts(ascending=True)
# Out:
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# Staten Island      373
# Bronx             1091
# Queens            5666
# Brooklyn         20104
# Manhattan        21661
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# ## Show the average accommodation price for each neighbourhood

# %%
airbnb_nyc[['neighbourhood_group', 'price']].groupby('neighbourhood_group').mean().reset_index().sort_values('price')
# Out:
#   neighbourhood_group  price
# 0               Bronx  87.50
# 3              Queens  99.52
# 4       Staten Island 114.81
# 1            Brooklyn 124.38
# 2           Manhattan 196.88

# %% [markdown]
# ## Show how many accommodations are in each neighbourhood

# %%
airbnb_nyc[['neighbourhood_group', 'neighbourhood', 'id']].groupby(['neighbourhood_group', 'neighbourhood']).count()
# Out:
#                                    id
# neighbourhood_group neighbourhood
# Bronx               Allerton       42
#                     Baychester      7
#                     Belmont        24
#                     Bronxdale      19
#                     Castle Hill     9
# ...                                ..
# Staten Island       Tottenville     7
#                     West Brighton  18
#                     Westerleigh     2
#                     Willowbrook     1
#                     Woodrow         1
#
# [221 rows x 1 columns]

# %% [markdown]
# ## Making a csv file with the neighbourhood group and neighbourhoods with the count of the numbers of properties in each one

# %%
neighbourhoods = airbnb_nyc[['neighbourhood_group', 'neighbourhood', 'id']].groupby(['neighbourhood_group', 'neighbourhood']).count().reset_index()
neighbourhoods.rename(columns={'id':'n_accommodation'}, inplace=True)

neighbourhoods.to_csv('datasets/ny_neighbourhoods.csv')
